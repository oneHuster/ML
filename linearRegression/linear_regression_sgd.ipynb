# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# def load_datas():
datas = pd.read_csv("ex0.txt",sep='\t',header=None)
print datas
# Out:
#        0         1         2
# 0    1.0  0.067732  3.176513
# 1    1.0  0.427810  3.816464
# 2    1.0  0.995731  4.550095
# 3    1.0  0.738336  4.256571
# 4    1.0  0.981083  4.560815
# 5    1.0  0.526171  3.929515
# 6    1.0  0.378887  3.526170
# 7    1.0  0.033859  3.156393
# 8    1.0  0.132791  3.110301
# 9    1.0  0.138306  3.149813
# 10   1.0  0.247809  3.476346
# 11   1.0  0.648270  4.119688
# 12   1.0  0.731209  4.282233
# 13   1.0  0.236833  3.486582
# 14   1.0  0.969788  4.655492
# 15   1.0  0.607492  3.965162
# 16   1.0  0.358622  3.514900
# 17   1.0  0.147846  3.125947
# 18   1.0  0.637820  4.094115
# 19   1.0  0.230372  3.476039
# 20   1.0  0.070237  3.210610
# 21   1.0  0.067154  3.190612
# 22   1.0  0.925577  4.631504
# 23   1.0  0.717733  4.295890
# 24   1.0  0.015371  3.085028
# 25   1.0  0.335070  3.448080
# 26   1.0  0.040486  3.167440
# 27   1.0  0.212575  3.364266
# 28   1.0  0.617218  3.993482
# 29   1.0  0.541196  3.891471
# ..   ...       ...       ...
# 170  1.0  0.218023  3.380820
# 171  1.0  0.869778  4.565020
# 172  1.0  0.196830  3.279973
# 173  1.0  0.958178  4.554241
# 174  1.0  0.972673  4.633520
# 175  1.0  0.745797  4.281037
# 176  1.0  0.445674  3.844426
# 177  1.0  0.470557  3.891601
# 178  1.0  0.549236  3.849728
# 179  1.0  0.335691  3.492215
# 180  1.0  0.884739  4.592374
# 181  1.0  0.918916  4.632025
# 182  1.0  0.441815  3.756750
# 183  1.0  0.116598  3.133555
# 184  1.0  0.359274  3.567919
# 185  1.0  0.814811  4.363382
# 186  1.0  0.387125  3.560165
# 187  1.0  0.982243  4.564305
# 188  1.0  0.780880  4.215055
# 189  1.0  0.652565  4.174999
# 190  1.0  0.870030  4.586640
# 191  1.0  0.604755  3.960008
# 192  1.0  0.255212  3.529963
# 193  1.0  0.730546  4.213412
# 194  1.0  0.493829  3.908685
# 195  1.0  0.257017  3.585821
# 196  1.0  0.833735  4.374394
# 197  1.0  0.070095  3.213817
# 198  1.0  0.527070  3.952681
# 199  1.0  0.116163  3.129283
#
# [200 rows x 3 columns]

# %%
x,y = datas[1],datas[2]

# %%
# plt.plot(x,y,label="$sin(x)$",color="red",linewidth=2)
plt.scatter(x,y, color = 'm', label='1', s = 1)  
plt.show()

# %%
import time
# from matplotlib.animation import FuncAnimation

alpha = 0.01
a = np.random.normal()
b = np.random.normal()
def h(x):
    return a*x+b

maxround = 30
# fig = plt.figure()
# ax = fig.add_subplot(111)
# ax.scatter(x,y, color = 'm', label='1', s = 10)
for i in range(maxround):
    sum_a = 0 
    for xi,yi in zip(x,y):
        sum_a = sum_a + alpha*(yi - h(xi))*xi
    a = a + sum_a  
    
#     plt.clf()    
    plt.scatter(x,y, color = 'm', label='1', s = 1)  
    plt.plot(x,h(x),color="red",linewidth=2)  
    plt.show()
#     time.sleep(3) #make changes more apparent/easy to see
#     Y = np.random.rand(100, 3)*5
#  ax.cla() 
    
#     ax.cla()
#     ax.plot(x,h(x),linewidth=2)  
#     plt.draw()

# ln, = plt.plot([], [], 'ro', animated=True)
# def update(frame):

#     xdata.append(frame)
#     ydata.append(np.sin(frame))
#     ln.set_data(xdata, ydata)
#     return ln
# animation = FuncAnimation(fig, update, interval=10, blit=True, frames=30)
# plt.show()

# %%
x_train = np.array([    [1, 2],    [2, 1],    [2, 3],    [3, 5],    [1, 3],    [4, 2],    [7, 3],    [4, 5],    [11, 3],    [8, 7]    ])
y_train = np.array([7, 8, 10, 14, 8, 13, 20, 16, 28, 26])
x_train.shape
# Out:
# (10, 2)

# %%
def stochastic_gradient_descent(x,y,theta,alpha,m,max_iter):
    """随机梯度下降法，每一次梯度下降只使用一个样本。

    :param x: 训练集种的自变量
    :param y: 训练集种的因变量
    :param theta: 待求的权值
    :param alpha: 学习速率
    :param m: 样本总数
    :param max_iter: 最大迭代次数
    """
    deviation = 1
    iter = 0    
    flag = 0
    while True:
        for i in range(m):  #循环取训练集中的一个
            deviation = 0
            h = theta[0] * x[i]+theta[1]#[0] + theta[1] * x[i][1]
            theta[0] = theta[0] + alpha * (y[i] - h)*x[i]#[0] 
            theta[1] = theta[1] + alpha * (y[i] - h)

            iter = iter + 1
          
            #计算误差
            for i in range(m):
                deviation = deviation + (y[i] - (theta[0] * x[i]+theta[1]))**2#[0] + theta[1] * x[i][1])) ** 2
            if deviation <EPS or iter >max_iter:
                flag = 1 
                break
        if flag == 1 :
            break   
    return theta, iter

# %%
theta = [np.random.normal(),np.random.normal()]
EPS = 0.0001 
theta,iter = stochastic_gradient_descent(x,y,theta,0.01,len(x),max_iter=1000)
# theta
plt.scatter(x,y, color = 'm', label='1', s = 1)  
plt.plot(x,theta[0]*x+theta[1],color="red",linewidth=2)  
plt.show()

# %%
theta
# Out:
# [1.8301344846116465, 2.9362593554088869]
